--header="Connection: keep-alive" "https://drive.usercontent.google.com/download?id=1kHzGkzBe_QxNjA_HdDB8h64SIePYKWAc&export=download&authuser=3&confirm=t&uuid=0830bd2b-967c-4de7-982f-15ce43ed5af4&at=APZUnTWg4YEKCIcnI6T8twxZT39_:1710172170072" -c -O 'best_noise_detection_model.h5'import os

import os
import shutil
import random
import glob
import pandas as pd
from PIL import Image

def rename_images(main_folders):
  for folder in main_folders:
    for filename in os.listdir(folder):
      # Extract the file extension and last part of the name
      file_extension = os.path.splitext(filename)[1]
      new_name = os.path.splitext(filename.split("_")[-1])[0] + file_extension

      # Construct the full paths for old and new filenames
      old_path = os.path.join(folder, filename)
      new_path = os.path.join(folder, new_name)

      # Rename the image
      os.rename(old_path, new_path)

# Replace with your actual folder paths
main_folders = ["/content/DataSet2/With-Noise", "/content/DataSet2/Without-Noise"]

# Call the function to rename images
rename_images(main_folders)

print("Images renamed successfully!")
# Out:
# rm: cannot remove '/content/noisy-test': No such file or directory
# rm: cannot remove '/content/noise-free-test': No such file or directory
# --2024-03-12 07:16:29--  https://drive.usercontent.google.com/download?id=18UXIh3mGA_M0oxlapPIrUG-VVpF6PN2S&export=download&authuser=0&confirm=t&uuid=c9145a8e-164e-41ef-b861-5a58b8c96abc&at=APZUnTUCWp10XjwtXxQNcPZXSt28%3A1707724591017
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 416 Requested range not satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# Archive:  Phase2.zip
#    creating: DataSet2/
#    creating: DataSet2/Without-Noise/
#   inflating: DataSet2/Without-Noise/cast_def_0_0.jpeg
#   inflating: DataSet2/Without-Noise/cast_def_0_2.jpeg
#   inflating: DataSet2/Without-Noise/cast_def_0_22.jpeg
# ...

# %%
from PIL import Image

def resize_images(folder_path, target_size=(224, 224)):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            img = image.load_img(file_path, target_size=target_size)
            img.save(file_path)

resize_images("/content/DataSet2/With-Noise")
resize_images("/content/DataSet2/Without-Noise")
print ("resized status: OK!")
# Out:
# resized status: OK!

# %%
#train-test splitting

data_dir = "/content/DataSet2"
with_noise_dir = os.path.join(data_dir, "With-Noise")
without_noise_dir = os.path.join(data_dir, "Without-Noise")

main_folders = [with_noise_dir, without_noise_dir]

test_subfolders = ["/content/DataSet2/noisy-test", "/content/DataSet2/noise-free-test"]

percentage_to_move = 0.25 # Define the percentage of images to move to the test subfolders

for subfolder in test_subfolders:
    os.makedirs(subfolder, exist_ok=True)

image_with_noise = os.listdir(main_folders[0])
image_without_noise = os.listdir(main_folders[1])

image_with_noise.sort()  # Sort the image files to ensure consistency
image_without_noise.sort()
num_images_to_move = int(min(len(image_with_noise), len(image_without_noise)) * percentage_to_move)
indices_to_move = random.sample(range(len(image_with_noise)), num_images_to_move)

for idx in indices_to_move:  # Move the selected images to the test subfolders
    img_with_noise = image_with_noise[idx]
    img_without_noise = image_without_noise[idx]

    src_path_with_noise = os.path.join(main_folders[0], img_with_noise)
    src_path_without_noise = os.path.join(main_folders[1], img_without_noise)

    dst_path_with_noise = os.path.join(test_subfolders[0], img_with_noise)
    dst_path_without_noise = os.path.join(test_subfolders[1], img_without_noise)

    shutil.move(src_path_with_noise, dst_path_with_noise)
    shutil.move(src_path_without_noise, dst_path_without_noise)

print(f"Moved '{img_with_noise}' and '{img_without_noise}' to test subfolders.")
# Out:
# Moved '8668.jpeg' and '8668.jpeg' to test subfolders.

# %%
import cv2
import os
import numpy as np

with_noise_dir = "/content/DataSet2/With-Noise"
without_noise_dir = "/content/DataSet2/Without-Noise"

X_train = []
Y_train = []

# make list of filenames in both folders and sort them
with_noise_files = sorted(os.listdir(with_noise_dir))
without_noise_files = sorted(os.listdir(without_noise_dir))

# Iterate over the sorted filenames
for with_noise_filename, without_noise_filename in zip(with_noise_files, without_noise_files):

    with_noise_img_path = os.path.join(with_noise_dir, with_noise_filename)
    without_noise_img_path = os.path.join(without_noise_dir, without_noise_filename)

    with_noise_img = cv2.imread(with_noise_img_path)
    without_noise_img = cv2.imread(without_noise_img_path)

    # Check if images are loaded successfully
    if with_noise_img is not None and without_noise_img is not None:
        # Append preprocessed images to lists
        X_train.append(with_noise_img)
        Y_train.append(without_noise_img)
    else:
        print(f"Error loading images for filenames '{with_noise_filename}' and '{without_noise_filename}'.")

# Convert lists to numpy arrays
X_train = np.array(X_train)/255.
Y_train = np.array(Y_train)/255.

print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)

# %%
import keras.layers as layers
import keras.models as models
from keras.initializers import orthogonal
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf

def Conv2DLayer(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2D(filters, kernel_size=kernel, strides=strides, padding=padding,
                      kernel_initializer=kernel_init, name=prefix+'conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.15, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x

def Transpose_Conv2D(x, filters, kernel, strides, padding, block_id, kernel_init=orthogonal()):
    prefix = f'block_{block_id}_'
    x = layers.Conv2DTranspose(filters, kernel_size=kernel, strides=strides, padding=padding,
                               kernel_initializer=kernel_init, name=prefix+'de-conv')(x)
    x = layers.LeakyReLU(name=prefix+'lrelu')(x)
    x = layers.Dropout(0.15, name=prefix+'drop')((x))
    x = layers.BatchNormalization(name=prefix+'conv_bn')(x)
    return x

def AutoEncdoer(input_shape):
    inputs = layers.Input(shape=input_shape)
    # 256 x 256
    conv1 = Conv2DLayer(inputs, 196, 3, strides=1, padding='same', block_id=1)
    conv2 = Conv2DLayer(conv1, 196, 3, strides=2, padding='same', block_id=2)
    # 128 x 128
    conv3 = Conv2DLayer(conv2, 256, 5, strides=2, padding='same', block_id=3)
    # 64 x 64
    conv4 = Conv2DLayer(conv3, 256, 3, strides=1, padding='same', block_id=4)
    conv5 = Conv2DLayer(conv4, 256, 5, strides=2, padding='same', block_id=5)
    # 32 x 32
    conv6 = Conv2DLayer(conv5, 512, 3, strides=2, padding='same', block_id=6)
    # 16 x 16
    deconv1 = Transpose_Conv2D(conv6, 512, 3, strides=2, padding='same', block_id=7)

    # 32 x 32
    skip1 = layers.concatenate([deconv1, conv5], name='skip1')
    conv7 = Conv2DLayer(skip1, 256, 3, strides=1, padding='same', block_id=8)
    deconv2 = Transpose_Conv2D(conv7, 128, 3, strides=2, padding='same', block_id=9)

    # 64 x 64
    skip2 = layers.concatenate([deconv2, conv3], name='skip2')
    conv8 = Conv2DLayer(skip2, 256, 5, strides=1, padding='same', block_id=10)
    deconv3 = Transpose_Conv2D(conv8, 64, 3, strides=2, padding='same', block_id=11)
    # 128 x 128
    skip3 = layers.concatenate([deconv3, conv2], name='skip3')
    conv9 = Conv2DLayer(skip3,196, 5, strides=1, padding='same', block_id=12)
    deconv4 = Transpose_Conv2D(conv9, 64, 3, strides=2, padding='same', block_id=13)
    # 256 x 256
    skip3 = layers.concatenate([deconv4, conv1])
    conv10 = layers.Conv2D(3, 3, strides=1, padding='same', activation='sigmoid',
                       kernel_initializer=orthogonal(), name='final_conv')(skip3)

    return models.Model(inputs=inputs, outputs=conv10)

input_shape = (224, 224, 3)
model = AutoEncdoer(input_shape)

# %%
from tensorflow.keras.callbacks import LearningRateScheduler,ReduceLROnPlateau, ModelCheckpoint
batch_size = 16
epochs = 15
input_shape = (224, 224, 3)
model = AutoEncdoer(input_shape)

model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=4),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,verbose=1,patience=4,min_delta=0.0001),
     tf.keras.callbacks.ModelCheckpoint('/content/DataSet2/best_denoiser_model.h5', monitor='acc', save_best_only=True)
]

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.15,callbacks=callbacks)

# Save the trained model
model.save_weights('/content/DataSet2/denoiser_weights.h5')
# Out:
# Epoch 1/15
# 58/58 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.3322
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 46s 406ms/step - loss: 0.0167 - accuracy: 0.3322 - val_loss: 0.0734 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 2/15
# 58/58 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.3297
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 20s 348ms/step - loss: 0.0074 - accuracy: 0.3297 - val_loss: 0.0512 - val_accuracy: 0.3027 - lr: 0.0010
# Epoch 3/15
# 58/58 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.3270
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 58/58 [==============================] - 20s 348ms/step - loss: 0.0055 - accuracy: 0.3270 - val_loss: 0.0614 - val_accuracy: 0.6870 - lr: 0.0010
# Epoch 4/15
# ...

# %%
tf.keras.utils.plot_model(model, to_file='/content/model-plot.png', show_shapes=True, show_layer_names=True)

# %%
import matplotlib.pyplot as plt
from keras.models import load_model

test_image_path = "/content/DataSet2/noisy-test/5609.jpeg"
test_image = cv2.imread(test_image_path)
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

original_image_path = "/content/DataSet2/noise-free-test/5609.jpeg"
original_image = cv2.imread(original_image_path)
original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

# Preprocess the image (resize and normalize)
test_image = cv2.resize(test_image, (224, 224))  # Resize to match the input shape of your model
test_image = test_image / 255.0  # Normalize pixel values

# Expand dimensions to create a batch of size 1
test_image = np.expand_dims(test_image, axis=0)

# Use the model to predict the denoised image
denoised_image = model.predict(test_image)

# Visualize the original noisy image and the denoised image
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title("Noisy Image")
plt.imshow(test_image[0], cmap='RdBu')  # Use 'gray' for better visualization
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Denoised Image")
plt.imshow(denoised_image[0], cmap='RdBu')  # Use 'gray' for better visualization
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("Original Image")
plt.imshow(original_image, cmap='RdBu')  # Use 'gray' for better visualization
plt.axis('off')

plt.tight_layout()  # Adjust spacing between subplots

plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
denoised_image = cv2.normalize(denoised_image, None, 0, 255, cv2.NORM_MINMAX).reshape(224,224, 3)

# %%
# !pip install lpips
import torch
import lpips
import numpy as np
import cv2
from skimage.metrics import structural_similarity as ssim

ground = cv2.imread("/content/DataSet2/noise-free-test/5609.jpeg", cv2.IMREAD_COLOR)
ground_rgb = cv2.cvtColor(ground, cv2.COLOR_BGR2RGB)

# Convert the RGB images to PyTorch tensors
ground_truth_tensor = torch.from_numpy(ground_rgb).permute(2, 0, 1).float() / 255.0
denoised_tensor = torch.from_numpy(denoised_image).permute(2, 0, 1).float() / 255.0

# Calculate LPIPS
lpips_loss = lpips.LPIPS(net='alex')
lpips_score = lpips_loss(ground_truth_tensor, denoised_tensor)

# Calculate PSNR
mse = np.mean((ground_rgb - denoised_image) ** 2)
psnr_score = 20 * np.log10(255 / np.sqrt(mse))

# Calculate SSIM
ssim_score = ssim(ground_rgb, denoised_image, multichannel=True)

print("LPIPS Score:  %", round(lpips_score.item()*100,3))
print("PSNR Score:", round(psnr_score ,3))
print("SSIM Score: %", round(ssim_score * 100 ,3))
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# LPIPS Score:  % 2.831
# PSNR Score: 25.477
# SSIM Score: % 85.665
# <ipython-input-16-fdd34ef46764>:24: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_score = ssim(ground_rgb, denoised_image, multichannel=True)

# %%
#load the best noise reduction model (Autoencoder)
from keras.models import load_model
# !wget --header="Host: drive.usercontent.google.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-US,en;q=0.9,fa;q=0.8" --header="Cookie: HSID=AVZaa1f5ErIEtLvcQ; SSID=Awf3XhMFJkemeGrY_; APISID=oRIlfG55p19VZpcr/A7Mj475R1IXF1DkbI; SAPISID=wKEwIU5TeyVYC2ac/AvFuZHnZAzf78Ftge; __Secure-1PAPISID=wKEwIU5TeyVYC2ac/AvFuZHnZAzf78Ftge; __Secure-3PAPISID=wKEwIU5TeyVYC2ac/AvFuZHnZAzf78Ftge; AMP_MKTG_630874745a=JTdCJTdE; AEC=Ae3NU9PERSlemibeYmMyedaimM4SxvIUXlqa-lfsz
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import torch
import lpips
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim

def prepare(img_path):
    img = image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = x/255
    return np.expand_dims(x, axis=0)

def cal_periodic_gaussian(img_name):
  test_image_path = "/content/DataSet2/noisy-test/"+ img_name
  test_image = cv2.imread(test_image_path)
  test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

  original_image_path = "/content/DataSet2/noise-free-test/"+ img_name
  original_image = cv2.imread(original_image_path)
  original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

  # Preprocess the image (resize and normalize)
  test_image = cv2.resize(test_image, (224, 224))  # Resize to match the input shape of your model
  test_image = test_image / 255.0  # Normalize pixel values

  # Expand dimensions to create a batch of size 1
  test_image = np.expand_dims(test_image, axis=0)

  # Use the model to predict the denoised image
  denoised_image = denoiser_model.predict(test_image)

  # Convert the RGB images to PyTorch tensors
  denoised_image = cv2.normalize(denoised_image, None, 0, 255, cv2.NORM_MINMAX).reshape(224,224, 3)

  ground = cv2.imread("/content/DataSet2/noise-free-test/"+ img_name , cv2.IMREAD_COLOR)
  ground_rgb = cv2.cvtColor(ground, cv2.COLOR_BGR2RGB)

  # Convert the RGB images to PyTorch tensors
  ground_truth_tensor = torch.from_numpy(ground_rgb).permute(2, 0, 1).float() / 255.0
  denoised_tensor = torch.from_numpy(denoised_image).permute(2, 0, 1).float() / 255.0

  # Calculate LPIPS
  lpips_loss = lpips.LPIPS(net='alex')
  lpips_score = lpips_loss(ground_truth_tensor, denoised_tensor)

  # Calculate PSNR
  mse = np.mean((ground_rgb - denoised_image) ** 2)
  psnr_score = 20 * np.log10(255 / np.sqrt(mse))
  # Calculate SSIM
  ssim_score = ssim(ground_rgb, denoised_image, multichannel=True)

  return (round(lpips_score.item()*100,3),round(psnr_score ,3) ,round(ssim_score * 100 ,3)  )

def cal_salt(img_name):
  noisyimage = cv2.imread('/content/DataSet2/noisy-test/'+img_name , cv2.IMREAD_COLOR)

  # Apply median filter several times
  filtered_image = cv2.medianBlur(noisyimage, 3)  # Kernel size of 3
  filtered_image = cv2.medianBlur(filtered_image,3)
  filtered_image = cv2.medianBlur(filtered_image,3)

  # Convert BGR to RGB for displaying with Matplotlib
  filtered_image_rgb = cv2.cvtColor(filtered_image, cv2.COLOR_BGR2RGB)

  ground = cv2.imread('/content/DataSet2/noise-free-test/'+img_name, cv2.IMREAD_COLOR)
  ground_rgb = cv2.cvtColor(ground, cv2.COLOR_BGR2RGB)

  # Convert the RGB images to PyTorch tensors
  ground_truth_tensor = torch.from_numpy(ground_rgb).permute(2, 0, 1).float() / 255.0
  denoised_tensor = torch.from_numpy(filtered_image_rgb).permute(2, 0, 1).float() / 255.0

  # Calculate LPIPS
  lpips_loss = lpips.LPIPS(net='alex')
  lpips_score = lpips_loss(ground_truth_tensor, denoised_tensor)

  # Calculate PSNR
  mse = np.mean((ground_rgb - filtered_image_rgb) ** 2)
  psnr_score = 20 * np.log10(255 / np.sqrt(mse))
  ssim_score = ssim(ground_rgb, filtered_image_rgb, multichannel=True)
  return (round(lpips_score.item()*100,3),round(psnr_score ,3) ,round(ssim_score * 100 ,3)  )

# %%
#load the best noise detection model (VGG16 frequency domain)
from keras.models import load_model
# !wget --header="Host: drive.usercontent.google.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7" --header="Accept-Language: en-US,en;q=0.
--header="Connection: keep-alive" "https://drive.usercontent.google.com/download?id=1-8p5Dhg7cFNwaeVq_8hBXLdrSmhMcq27&export=download&authuser=3&confirm=t&uuid=6ece440b-52a8-44a4-89a5-2b3078f0ab47&at=APZUnTXC5II6HlaxDQN6MPb4F7D0:1710221385879" -c -O 'vgg16_Freq_Classification.h5'
noise_classify_model = load_model("/content/vgg16_Freq_Classification.h5")
# Out:
# --2024-03-12 06:14:58--  https://drive.usercontent.google.com/download?id=1-8p5Dhg7cFNwaeVq_8hBXLdrSmhMcq27&export=download&authuser=3&confirm=t&uuid=6ece440b-52a8-44a4-89a5-2b3078f0ab47&at=APZUnTXC5II6HlaxDQN6MPb4F7D0:1710221385879
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.162.132, 2607:f8b0:400c:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.162.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image


classes= ['Gaussian', 'Periodic', 'Salt']

# Load all image files from the specified directory
img_folder = '/content/DataSet2/noisy-test'

periodic_psnr = []
gaussian_psnr = []
salt_psnr = []
periodic_lpips = []
gaussian_lpips = []
salt_lpips = []
periodic_ssim = []
gaussian_ssim = []
salt_ssim = []

for img_name in os.listdir(img_folder):
    img_path = os.path.join(img_folder, img_name)

    result = noise_classify_model.predict([prepare(img_path)])
    classresult=np.argmax(result,axis=1)
    # Perform noise detection on the image
    if (classes[classresult[0]] == 'Periodic'):

      lpips1 ,psnr1 , ssim1  =cal_periodic_gaussian(img_name)
      periodic_ssim.append( ssim1)
      periodic_psnr.append(psnr1)
      periodic_lpips.append(lpips1 )
      print("Periodic PSNR is : " + str(psnr1))

    elif (classes[classresult[0]] == 'Gaussian'):
      lpips2 ,psnr2 , ssim2  =cal_periodic_gaussian(img_name)
      gaussian_ssim.append( ssim2)
      gaussian_psnr.append(psnr2)
      gaussian_lpips.append(lpips2 )
      print("Gaussian PSNR is : " + str(psnr2))


    elif (classes[classresult[0]] == 'Salt'):

      lpips3 ,psnr3 , ssim3  = cal_salt(img_name)
      salt_ssim.append(ssim3)
      salt_psnr.append(psnr3)
      salt_lpips.append(lpips3)
      print("Salt PSNR is : " + str(psnr3))
# Out:
# 1/1 [==============================] - 1s 1s/step
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# Salt PSNR is : 35.052
# ...

# %%
print("---> Medain filter result  <---- ")
print("-> Avg SSIM for Salt noise  : " + str(np.mean(salt_ssim).round(3)) + " ± " + str(np.std(salt_ssim).round(3)) + " and MAX is : " + str(np.max(salt_ssim)) )
print("-> Avg PSNR for Salt noise : " + str(np.mean(salt_psnr).round(3)) + " ± " +str(np.std(salt_psnr).round(3)) + " and MAX is : " + str(np.max(salt_psnr))  )
print("-> Avg LPIPS for Salt noise  : " + str(np.mean(salt_lpips).round(3)) + " ± "+ str(np.std(salt_lpips).round(3)) + " and MAX is : " + str(np.max(salt_lpips)) )
print("-> These results are valid for " + str(len(salt_psnr))+ " instances ! for random  25% percent of Dataset2!")
# Out:
# ---> Medain filter result  <----
# -> Avg SSIM for Salt noise  : 87.969 ± 1.507 and MAX is : 91.389
# -> Avg PSNR for Salt noise : 34.658 ± 0.485 and MAX is : 36.06
# -> Avg LPIPS for Salt noise  : 5.84 ± 1.269 and MAX is : 10.853
# -> These results are valid for 100 instances ! for random  25% percent of Dataset2!

# %%
print("---> Autoencoder result for gaussian noise  <---- ")
print("-> Avg SSIM for gaussian noise  : " + str(np.mean(gaussian_ssim).round(3)) + " ± " + str(np.std(gaussian_ssim).round(3)) + " and MAX is : " + str(np.max(gaussian_ssim)) )
print("-> Avg PSNR for gaussian noise : " + str(np.mean(gaussian_psnr).round(3)) + " ± " +str(np.std(gaussian_psnr).round(3)) + " and MAX is : " + str(np.max(gaussian_psnr))  )
print("-> Avg LPIPS for gaussian noise  : " + str(np.mean(gaussian_lpips).round(3)) + " ± "+ str(np.std(gaussian_lpips).round(3)) + " and MAX is : " + str(np.max(gaussian_lpips)) )
print("-> These results are valid for " + str(len(gaussian_psnr))+ " instances ! for random  25% percent of Dataset2!")
# Out:
# ---> Autoencoder result for gaussian noise  <----
# -> Avg SSIM for gaussian noise  : 64.047 ± 12.885 and MAX is : 88.32
# -> Avg PSNR for gaussian noise : 23.73 ± 1.734 and MAX is : 27.756
# -> Avg LPIPS for gaussian noise  : 18.984 ± 10.682 and MAX is : 46.763
# -> These results are valid for 107 instances ! for random  25% percent of Dataset2!

# %%
print("---> Autoencoder result for Periodic noise  <---- ")
print("-> Avg SSIM for Periodic noise  : " + str(np.mean(periodic_ssim).round(3)) + " ± " + str(np.std(periodic_ssim).round(3)) + " and MAX is : " + str(np.max(periodic_ssim)) )
print("-> Avg PSNR for Periodic noise : " + str(np.mean(periodic_psnr).round(3)) + " ± " +str(np.std(periodic_psnr).round(3)) + " and MAX is : " + str(np.max(periodic_psnr))  )
print("-> Avg LPIPS for Periodic noise  : " + str(np.mean(periodic_lpips).round(3)) + " ± "+ str(np.std(periodic_lpips).round(3)) + " and MAX is : " + str(np.max(periodic_lpips)) )
print("-> These results are valid for " + str(len(periodic_psnr))+ " instances ! for random  25% percent of Dataset2!")
# Out:
# ---> Autoencoder result for Periodic noise  <----
# -> Avg SSIM for Periodic noise  : 81.696 ± 4.753 and MAX is : 87.542
# -> Avg PSNR for Periodic noise : 22.831 ± 3.047 and MAX is : 26.824
# -> Avg LPIPS for Periodic noise  : 5.124 ± 2.143 and MAX is : 13.031
# -> These results are valid for 96 instances ! for random  25% percent of Dataset2!

# %%
model.save('/content/denoiser_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/denoiser_model.h5 /content/drive/MyDrive/
# Out:
# Mounted at /content/drive

# %%
import keras.utils as image

classes=['Gaussian', 'Periodic', 'Salt']
def prepare(img_path):
    img = image.load_img(img_path, target_size=(224,224))
    x = image.img_to_array(img)
    x = x/255
    return np.expand_dims(x, axis=0)

img_url='/content/DataSet2/noisy-test/7523.jpeg'
result = noise_classify_model.predict([prepare(img_url)])
casting_img=image.load_img(img_url)
plt.imshow(casting_img)

classresult=np.argmax(result,axis=1)
print(classes[classresult[0]])
# Out:
# 1/1 [==============================] - 1s 781ms/step
# Salt
